# %% [markdown]
# ### Download panel data from World bank indicators using the WBdata library in Python.
# **Author:**
# Brahim Zirari <br>
# **Version:**
# Python 3.13.5 <br>
# **Topic:** GDP (current US$) data for Algeria, Tunisia, and Egypt for the period 2010-2022. <br>
# **Watch** Video.
# <a href = "https://www.youtube.com/watch?v=GA88oEWoB9Y" > Click here </a>

# %% [markdown]
# # Install and Import WBdata

# %%
! pip3 install -U wbdata

# %%
import wbdata

# %%
# Get World Bank various databases
wbdata.get_sources()
# Out:
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Findex database
#   29  The Atlas of Social Protection: Indicators of Resilience and Equity
#   30  Exporter Dynamics Database – Indicators at Country-Year Level
#   31  Country Policy and Institutional Assessment
#   32  Global Financial Development
#   33  G20 Financial Inclusion Indicators
#   34  Global Partnership for Education
#   35  Sustainable Energy for All
#   37  LAC Equity Lab
#   38  Subnational Poverty
#   39  Health Nutrition and Population Statistics by Wealth Quintile
#   40  Population estimates and projections
#   41  Country Partnership Strategy for India (FY2013 - 17)
#   43  Adjusted Net Savings
#   45  Indonesia Database for Policy and Economic Research
#   46  Sustainable Development Goals
#   50  Subnational Population
#   54  Joint External Debt Hub
#   57  WDI Database Archives
#   58  Universal Health Coverage
#   59  Wealth Accounts
#   60  Economic Fitness
#   61  PPPs Regulatory Quality
#   62  International Comparison Program (ICP) 2011
#   63  Human Capital Index
#   64  Worldwide Bureaucracy Indicators
#   65  Health Equity and Financial Protection Indicators
#   66  Logistics Performance Index
#   67  PEFA 2011
#   68  PEFA 2016
#   69  Global Financial Inclusion and Consumer Protection Survey
#   70  Economic Fitness 2
#   71  International Comparison Program (ICP) 2005
#   73  Global Financial Inclusion and Consumer Protection Survey (Internal)
#   75  Environment, Social and Governance (ESG) Data
#   76  Remittance Prices Worldwide (Sending Countries)
#   77  Remittance Prices Worldwide (Receiving Countries)
#   78  ICP 2017
#   79  PEFA_GRPFM
#   80  Gender Disaggregated Labor Database (GDLD)
#   81  International Debt Statistics: DSSI
#   82  Global Public Procurement
#   83  Statistical Performance Indicators (SPI)
#   84  Education Policy
#   85  PEFA_2021_SNG
#   86  Global Jobs Indicators Database (JOIN)
#   87  Country Climate and Development Report (CCDR)
#   88  Food Prices for Nutrition
#   89  Identification for Development (ID4D) Data
#   90  ICP 2021
#   91  PEFA_CRPFM
#   92  Disability Data Hub (DDH)

# %%
# Get indicators (GDP) from the WDI source 02
wbdata.get_indicators(source=2, query= 'GDP') #NY.GDP.MKTP.CD
# Out:
# id                       name
# -----------------------  ------------------------------------------------------------------------------------------------
# BG.GSR.NFSV.GD.ZS        Trade in services (% of GDP)
# BM.KLT.DINV.WD.GD.ZS     Foreign direct investment, net outflows (% of GDP)
# BN.CAB.XOKA.GD.ZS        Current account balance (% of GDP)
# BX.KLT.DINV.WD.GD.ZS     Foreign direct investment, net inflows (% of GDP)
# BX.TRF.PWKR.DT.GD.ZS     Personal remittances, received (% of GDP)
# CM.MKT.LCAP.GD.ZS        Market capitalization of listed domestic companies (% of GDP)
# CM.MKT.TRAD.GD.ZS        Stocks traded, total value (% of GDP)
# EG.EGY.PRIM.PP.KD        Energy intensity level of primary energy (MJ/$2017 PPP GDP)
# EG.GDP.PUSE.KO.PP        GDP per unit of energy use (PPP $ per kg of oil equivalent)
# EG.GDP.PUSE.KO.PP.KD     GDP per unit of energy use (constant 2021 PPP $ per kg of oil equivalent)
# EG.USE.COMM.GD.PP.KD     Energy use (kg of oil equivalent) per $1,000 GDP (constant 2021 PPP)
# EN.GHG.CO2.RT.GDP.KD     Carbon intensity of GDP (kg CO2e per constant 2015 US$ of GDP)
# EN.GHG.CO2.RT.GDP.PP.KD  Carbon intensity of GDP (kg CO2e per 2021 PPP $ of GDP)
# ER.GDP.FWTL.M3.KD        Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)
# FD.AST.PRVT.GD.ZS        Domestic credit to private sector by banks (% of GDP)
# FM.AST.PRVT.GD.ZS        Monetary Sector credit to private sector (% GDP)
# FM.LBL.BMNY.GD.ZS        Broad money (% of GDP)
# FS.AST.CGOV.GD.ZS        Claims on central government, etc. (% GDP)
# FS.AST.DOMO.GD.ZS        Claims on other sectors of the domestic economy (% of GDP)
# FS.AST.DOMS.GD.ZS        Domestic credit provided by financial sector (% of GDP)
# FS.AST.PRVT.GD.ZS        Domestic credit to private sector (% of GDP)
# GB.XPD.RSDV.GD.ZS        Research and development expenditure (% of GDP)
# GC.AST.TOTL.GD.ZS        Net acquisition of financial assets (% of GDP)
# GC.DOD.TOTL.GD.ZS        Central government debt, total (% of GDP)
# GC.LBL.TOTL.GD.ZS        Net incurrence of liabilities, total (% of GDP)
# GC.NFN.TOTL.GD.ZS        Net investment in nonfinancial assets (% of GDP)
# GC.NLD.TOTL.GD.ZS        Net lending (+) / net borrowing (-) (% of GDP)
# GC.REV.XGRT.GD.ZS        Revenue, excluding grants (% of GDP)
# GC.TAX.TOTL.GD.ZS        Tax revenue (% of GDP)
# GC.XPN.TOTL.GD.ZS        Expense (% of GDP)
# MS.MIL.XPND.GD.ZS        Military expenditure (% of GDP)
# NE.CON.GOVT.ZS           General government final consumption expenditure (% of GDP)
# NE.CON.PRVT.ZS           Households and NPISHs final consumption expenditure (% of GDP)
# NE.CON.TOTL.ZS           Final consumption expenditure (% of GDP)
# NE.DAB.TOTL.ZS           Gross national expenditure (% of GDP)
# NE.EXP.GNFS.ZS           Exports of goods and services (% of GDP)
# NE.GDI.FPRV.ZS           Gross fixed capital formation, private sector (% of GDP)
# NE.GDI.FTOT.ZS           Gross fixed capital formation (% of GDP)
# NE.GDI.TOTL.ZS           Gross capital formation (% of GDP)
# NE.IMP.GNFS.ZS           Imports of goods and services (% of GDP)
# NE.RSB.GNFS.ZS           External balance on goods and services (% of GDP)
# NE.TRD.GNFS.ZS           Trade (% of GDP)
# NV.AGR.TOTL.ZS           Agriculture, forestry, and fishing, value added (% of GDP)
# NV.IND.MANF.ZS           Manufacturing, value added (% of GDP)
# NV.IND.TOTL.ZS           Industry (including construction), value added (% of GDP)
# NV.SRV.TOTL.ZS           Services, value added (% of GDP)
# NY.GDP.COAL.RT.ZS        Coal rents (% of GDP)
# NY.GDP.DEFL.KD.ZG        Inflation, GDP deflator (annual %)
# NY.GDP.DEFL.KD.ZG.AD     Inflation, GDP deflator: linked series (annual %)
# NY.GDP.DEFL.ZS           GDP deflator (base year varies by country)
# NY.GDP.DEFL.ZS.AD        GDP deflator: linked series (base year varies by country)
# NY.GDP.DISC.CN           Discrepancy in expenditure estimate of GDP (current LCU)
# NY.GDP.DISC.KN           Discrepancy in expenditure estimate of GDP (constant LCU)
# NY.GDP.FRST.RT.ZS        Forest rents (% of GDP)
# NY.GDP.MINR.RT.ZS        Mineral rents (% of GDP)
# NY.GDP.MKTP.CD           GDP (current US$)
# NY.GDP.MKTP.CN           GDP (current LCU)
# NY.GDP.MKTP.CN.AD        GDP: linked series (current LCU)
# NY.GDP.MKTP.KD           GDP (constant 2015 US$)
# NY.GDP.MKTP.KD.ZG        GDP growth (annual %)
# NY.GDP.MKTP.KN           GDP (constant LCU)
# NY.GDP.MKTP.PP.CD        GDP, PPP (current international $)
# NY.GDP.MKTP.PP.KD        GDP, PPP (constant 2021 international $)
# NY.GDP.NGAS.RT.ZS        Natural gas rents (% of GDP)
# NY.GDP.PCAP.CD           GDP per capita (current US$)
# NY.GDP.PCAP.CN           GDP per capita (current LCU)
# NY.GDP.PCAP.KD           GDP per capita (constant 2015 US$)
# NY.GDP.PCAP.KD.ZG        GDP per capita growth (annual %)
# NY.GDP.PCAP.KN           GDP per capita (constant LCU)
# NY.GDP.PCAP.PP.CD        GDP per capita, PPP (current international $)
# NY.GDP.PCAP.PP.KD        GDP per capita, PPP (constant 2021 international $)
# NY.GDP.PETR.RT.ZS        Oil rents (% of GDP)
# NY.GDP.TOTL.RT.ZS        Total natural resources rents (% of GDP)
# NY.GDS.TOTL.ZS           Gross domestic savings (% of GDP)
# NY.GNS.ICTR.ZS           Gross savings (% of GDP)
# PA.NUS.PPP               PPP conversion factor, GDP (LCU per international $)
# PA.NUS.PPPC.RF           Price level ratio of PPP conversion factor (GDP) to market exchange rate
# SE.XPD.PRIM.PC.ZS        Government expenditure per student, primary (% of GDP per capita)
# SE.XPD.SECO.PC.ZS        Government expenditure per student, secondary (% of GDP per capita)
# SE.XPD.TERT.PC.ZS        Government expenditure per student, tertiary (% of GDP per capita)
# SE.XPD.TOTL.GD.ZS        Government expenditure on education, total (% of GDP)
# SH.XPD.CHEX.GD.ZS        Current health expenditure (% of GDP)
# SH.XPD.GHED.GD.ZS        Domestic general government health expenditure (% of GDP)
# SL.GDP.PCAP.EM.KD        GDP per person employed (constant 2021 PPP $)
# TG.VAL.TOTL.GD.ZS        Merchandise trade (% of GDP)

# %%
# Get countries Iso code to collect data
#Tunisia
wbdata.get_countries(query='Tunisia')
# Out:
# id    name
# ----  ----------------
# EGY   Egypt, Arab Rep.

# %%
#Algeria
wbdata.get_countries(query='Algeria')
# Out:
# id    name
# ----  -------
# DZA   Algeria

# %%
#Egypt
wbdata.get_countries(query='Egypt')
# Out:
# id    name
# ----  ----------------
# EGY   Egypt, Arab Rep.

# %% [markdown]
# # Check data availability

# %%
# use indicator code NY.GDP.MKTP.CD and countries Iso code as a list EGY, DZA, TUN
wbdata.get_data('NY.GDP.MKTP.CD', country=['DZA', 'EGY', 'TUN'])
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2024',
#   'value': 263619794506.723,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2023',
#   'value': 247626161016.414,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2022',
#   'value': 225638456572.143,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2021',
#   'value': 186231205262.082,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2020',
#   'value': 164873415325.201,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2019',
#   'value': 193459662090.677,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2018',
#   'value': 194554483655.528,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2017',
#   'value': 189880896903.073,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2016',
#   'value': 180763839522.151,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2015',
#   'value': 187493855609.345,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2014',
#   'value': 238942664192.59,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2013',
#   'value': 229701430292.157,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2012',
#   'value': 227143746075.934,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2011',
#   'value': 218331946925.304,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2010',
#   'value': 177785053939.531,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2009',
#   'value': 150317292079.359,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2008',
#   'value': 180383848331.135,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2007',
#   'value': 142482739809.849,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2006',
#   'value': 123084258693.01,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2005',
#   'value': 107046618669.707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2004',
#   'value': 91913680985.1708,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2003',
#   'value': 73482264190.9245,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2002',
#   'value': 61516103406.1688,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2001',
#   'value': 59413400923.6364,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2000',
#   'value': 54790398570.3282,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1999',
#   'value': 48640671734.9711,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1998',
#   'value': 48187781984.4881,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1997',
#   'value': 48177612042.1507,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1996',
#   'value': 46941554225.3581,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1995',
#   'value': 41764291671.7711,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1994',
#   'value': 42543176828.9237,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1993',
#   'value': 49945584452.6506,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1992',
#   'value': 48003133346.9957,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1991',
#   'value': 45715676428.2766,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1990',
#   'value': 62048507531.3357,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1989',
#   'value': 55634721572.7343,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1988',
#   'value': 59089396860.4342,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1987',
#   'value': 66745818375.493,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1986',
#   'value': 63692007897.3834,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1985',
#   'value': 57937868670.1937,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1984',
#   'value': 53698548293.0745,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1983',
#   'value': 48801369800.3675,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1982',
#   'value': 45207167470.3497,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1981',
#   'value': 44348590460.9288,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1980',
#   'value': 42345829079.2062,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1979',
#   'value': 33243706859.6596,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1978',
#   'value': 26364491313.4471,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1977',
#   'value': 20972113684.9558,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1976',
#   'value': 17728240932.3158,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1975',
#   'value': 15557902754.033,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1974',
#   'value': 13209871625.9044,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1973',
#   'value': 8707858912.12481,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1972',
#   'value': 6766743956.88889,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1971',
#   'value': 5077183093.88968,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1970',
#   'value': 4863526896.57407,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1969',
#   'value': 4257253264.08834,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1968',
#   'value': 3852147026.77302,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1967',
#   'value': 3370870376.29682,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1966',
#   'value': 3039859187.45164,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1965',
#   'value': 3136284306.85469,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1964',
#   'value': 2909316435.2874,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1963',
#   'value': 2702982017.63803,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1962',
#   'value': 2001444543.91885,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1961',
#   'value': 2434747055.94018,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '1960',
#   'value': 2723615451.30098,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2024',
#   'value': 389059911003.566,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2023',
#   'value': 395926075163.006,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2022',
#   'value': 476747720364.742,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2021',
#   'value': 424671765455.704,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2020',
#   'value': 383817841547.099,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2019',
#   'value': 318678815489.749,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2018',
#   'value': 262588632526.73,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2017',
#   'value': 248362771739.13,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2016',
#   'value': 332441717791.411,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2015',
#   'value': 329366576819.407,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2014',
#   'value': 305595408895.265,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2013',
#   'value': 288434108527.132,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2012',
#   'value': 279116666666.667,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2011',
#   'value': 235989672977.625,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2010',
#   'value': 218983666061.706,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2009',
#   'value': 189147005444.646,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2008',
#   'value': 162818181818.182,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2007',
#   'value': 130437828371.278,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2006',
#   'value': 107426086956.522,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2005',
#   'value': 89660339660.3397,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2004',
#   'value': 78782467532.4675,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2003',
#   'value': 80288461538.4615,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2002',
#   'value': 85146067415.7303,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2001',
#   'value': 96684636118.5984,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2000',
#   'value': 99838543960.0763,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1999',
#   'value': 90710704806.8416,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1998',
#   'value': 84828807556.0803,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1997',
#   'value': 78436578171.0914,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1996',
#   'value': 67629716981.1321,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1995',
#   'value': 60159245060.4541,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1994',
#   'value': 51897983392.6453,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1993',
#   'value': 46578631452.581,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1992',
#   'value': 41855986519.4235,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1991',
#   'value': 37387836490.5284,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1990',
#   'value': 42978914311.3504,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1989',
#   'value': 39756299049.9793,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1988',
#   'value': 34980124929.0176,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1987',
#   'value': 40455616653.5742,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1986',
#   'value': 41253507951.3564,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1985',
#   'value': 39053502251.0732,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1984',
#   'value': 33971188991.6147,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1983',
#   'value': 30966239813.7369,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1982',
#   'value': 27655172413.7931,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1981',
#   'value': 22136081081.0811,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1980',
#   'value': 21669908176.3889,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1979',
#   'value': 18020571428.5714,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1978',
#   'value': 14811704063.0685,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1977',
#   'value': 14400806875.9867,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1976',
#   'value': 13315988083.4161,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1975',
#   'value': 11632178868.9171,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1974',
#   'value': 9228963224.60004,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1973',
#   'value': 10098534613.4411,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1972',
#   'value': 9299638055.84281,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1971',
#   'value': 8609283346.08518,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1970',
#   'value': 8042200452.1477,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1969',
#   'value': 6524455205.81114,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1968',
#   'value': 5932242990.65421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1967',
#   'value': 5605484298.98275,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1966',
#   'value': 5278005611.91453,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1965',
#   'value': 4948667540.41066,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1964',
#   'value': 4709245761.67881,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1963',
#   'value': 4187146231.56839,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1962',
#   'value': 4035462027.39753,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1961',
#   'value': 4494575611.21289,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '1960',
#   'value': 4206270352.22633,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2024',
#   'value': 53409988744.5968,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2023',
#   'value': 48196281783.9479,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2022',
#   'value': 44948769171.285,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2021',
#   'value': 47073234359.1819,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2020',
#   'value': 42491780918.361,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2019',
#   'value': 41905642418.825,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2018',
#   'value': 42686504459.801,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2017',
#   'value': 42163530590.9462,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2016',
#   'value': 44360072680.4476,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2015',
#   'value': 45779494041.9295,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2014',
#   'value': 50271812920.612,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2013',
#   'value': 48685446413.953,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2012',
#   'value': 47311401812.6733,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2011',
#   'value': 48123325825.0739,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2010',
#   'value': 46206091937.9628,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2009',
#   'value': 43455740497.3061,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2008',
#   'value': 44859439902.2191,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2007',
#   'value': 38915353866.757,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2006',
#   'value': 34376664600.5898,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2005',
#   'value': 32272186694.8043,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2004',
#   'value': 31183885241.4396,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2003',
#   'value': 27453902261.4629,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2002',
#   'value': 23141616604.5242,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2001',
#   'value': 22065832448.8623,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2000',
#   'value': 21473528160.7782,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1999',
#   'value': 22943202174.9668,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1998',
#   'value': 21802893587.126,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1997',
#   'value': 20746210353.845,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1996',
#   'value': 19587161806.7655,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1995',
#   'value': 18030876599.3444,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1994',
#   'value': 15633174304.0905,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1993',
#   'value': 14608335608.1543,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1992',
#   'value': 15496708060.4184,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1991',
#   'value': 13074782608.6957,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1990',
#   'value': 12290568181.8182,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1989',
#   'value': 10101851744.5627,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1988',
#   'value': 10096245762.4352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1987',
#   'value': 9696715910.70907,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1986',
#   'value': 9017806654.4169,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1985',
#   'value': 8410226052.6114,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1984',
#   'value': 8254541194.82566,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1983',
#   'value': 8350582747.83541,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1982',
#   'value': 8133580051.70251,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1981',
#   'value': 8428445294.08429,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1980',
#   'value': 8744134354.16152,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1979',
#   'value': 7188863903.63675,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1978',
#   'value': 5968460080.1113,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1977',
#   'value': 5109324009.32401,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1976',
#   'value': 4508191942.16081,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1975',
#   'value': 4328965587.53266,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1974',
#   'value': 3545868575.14639,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1973',
#   'value': 2730813385.32624,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1972',
#   'value': 2237556148.51085,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1971',
#   'value': 1685162272.40652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1970',
#   'value': 1439238095.2381,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1969',
#   'value': 1289904761.90476,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1968',
#   'value': 1214666666.66667,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1967',
#   'value': 1085714285.71429,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1966',
#   'value': 1040952380.95238,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1965',
#   'value': 991047619.047619,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1964',
#   'value': 1025866792.15686,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1963',
#   'value': 1026737600,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1962',
#   'value': 880027733.333333,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1961',
#   'value': 866155428.571429,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '1960',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %% [markdown]
# # Data are avaliable from 1960 to 2024

# %% [markdown]
# # Now! let us collect data for these countries from 2010 to 2022

# %%
df= wbdata.get_data('NY.GDP.MKTP.CD',country=['DZA', 'EGY', 'TUN'], date=('2020', '2010')) #df now is a dictionary

# %% [markdown]
# # Create a dataframe

# %%
import pandas as pd

# %%
data = pd.DataFrame(df)

#Choose value from country
data['country'] = data['country'].apply(lambda x: x['value'])
data = data[['date','country','value']]
print(data)
# Out:
#     date           country         value
# 0   2020           Algeria  1.648734e+11
# 1   2019           Algeria  1.934597e+11
# 2   2018           Algeria  1.945545e+11
# 3   2017           Algeria  1.898809e+11
# 4   2016           Algeria  1.807638e+11
# 5   2015           Algeria  1.874939e+11
# 6   2014           Algeria  2.389427e+11
# 7   2013           Algeria  2.297014e+11
# 8   2012           Algeria  2.271437e+11
# 9   2011           Algeria  2.183319e+11
# 10  2010           Algeria  1.777851e+11
# 11  2020  Egypt, Arab Rep.  3.838178e+11
# 12  2019  Egypt, Arab Rep.  3.186788e+11
# 13  2018  Egypt, Arab Rep.  2.625886e+11
# 14  2017  Egypt, Arab Rep.  2.483628e+11
# 15  2016  Egypt, Arab Rep.  3.324417e+11
# 16  2015  Egypt, Arab Rep.  3.293666e+11
# 17  2014  Egypt, Arab Rep.  3.055954e+11
# 18  2013  Egypt, Arab Rep.  2.884341e+11
# 19  2012  Egypt, Arab Rep.  2.791167e+11
# 20  2011  Egypt, Arab Rep.  2.359897e+11
# 21  2010  Egypt, Arab Rep.  2.189837e+11
# 22  2020           Tunisia  4.249178e+10
# 23  2019           Tunisia  4.190564e+10
# 24  2018           Tunisia  4.268650e+10
# 25  2017           Tunisia  4.216353e+10
# 26  2016           Tunisia  4.436007e+10
# 27  2015           Tunisia  4.577949e+10
# 28  2014           Tunisia  5.027181e+10
# 29  2013           Tunisia  4.868545e+10
# 30  2012           Tunisia  4.731140e+10
# 31  2011           Tunisia  4.812333e+10
# 32  2010           Tunisia  4.620609e+10

# %% [markdown]
# # Export data to excel file

# %%
data.to_excel('Pdata.xlsx', index=False)
print('Thank you')
# Out:
# Thank you
